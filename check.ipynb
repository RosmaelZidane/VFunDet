# %%
import dgl
from dgl import load_graphs

# %%
# graph check

codebertg = "/home/wp3/confmodel/VFunDet/sourcescripts/storage/cache/Graph/bigvul_linevd_codebert_pdg+raw/18483"
sbertg = "/home/wp3/confmodel/VFunDet/sourcescripts/storage/cache/Graph/bigvul_linevd_sbert_pdg+raw/18483"
wordvg = "/home/wp3/confmodel/VFunDet/sourcescripts/storage/cache/Graph/bigvul_linevd_word2vec_pdg+raw/18482"

# %%
gcb = load_graphs(codebertg)[0][0]
gcb.ndata
# Out:
# {'_FVULN': tensor([0., 0.]), '_VULN': tensor([0., 0.]), '_LINE': tensor([3, 2], dtype=torch.int32), '_RANDFEAT': tensor([[2.4851e-02, 3.6496e-02, 7.9135e-01, 8.8188e-01, 2.2735e-01, 2.3856e-01,
#          9.2648e-03, 5.2837e-01, 6.4661e-01, 4.9695e-01, 3.1297e-01, 8.5839e-01,
#          1.9488e-01, 6.0462e-01, 7.8072e-01, 4.8540e-01, 4.9015e-02, 9.8371e-01,
#          4.9010e-01, 8.3654e-01, 2.6738e-01, 8.1624e-03, 2.2617e-01, 6.3563e-02,
#          5.1689e-01, 8.3519e-01, 5.7291e-01, 3.5946e-01, 3.4645e-01, 2.5737e-01,
#          2.1019e-01, 7.8252e-01, 2.1066e-01, 6.1132e-01, 7.7565e-01, 4.1129e-01,
#          7.0098e-01, 6.8041e-01, 8.8137e-01, 1.4640e-01, 7.4412e-02, 9.4925e-01,
#          6.6432e-01, 8.8269e-01, 4.9525e-01, 1.4328e-01, 7.0394e-01, 2.1603e-01,
#          7.8443e-01, 4.8073e-01, 3.9480e-01, 7.4772e-01, 5.4098e-02, 9.3887e-01,
#          8.7627e-01, 5.5919e-01, 5.6377e-01, 3.2787e-03, 1.9410e-01, 7.4160e-01,
# ...

# %%
gsb = load_graphs(sbertg)[0][0]
gsb.ndata
# Out:
# {'_FVULN': tensor([0., 0.]), '_VULN': tensor([0., 0.]), '_LINE': tensor([3, 2], dtype=torch.int32), '_RANDFEAT': tensor([[0.1249, 0.4738, 0.2548, 0.4742, 0.4854, 0.0284, 0.6060, 0.5043, 0.2924,
#          0.8728, 0.9838, 0.7661, 0.7402, 0.2047, 0.3085, 0.6082, 0.7556, 0.5535,
#          0.1681, 0.5717, 0.9390, 0.1607, 0.1299, 0.9951, 0.3950, 0.3244, 0.6649,
#          0.5458, 0.4934, 0.8268, 0.8347, 0.9699, 0.2150, 0.8269, 0.8719, 0.3422,
#          0.0943, 0.9364, 0.5083, 0.3491, 0.7490, 0.5724, 0.9741, 0.3278, 0.8053,
#          0.0553, 0.2895, 0.9221, 0.1220, 0.7657, 0.5198, 0.9798, 0.8662, 0.7434,
#          0.7035, 0.0713, 0.4642, 0.5954, 0.5651, 0.5901, 0.7035, 0.6887, 0.1667,
#          0.4841, 0.1502, 0.3333, 0.2141, 0.9694, 0.0787, 0.7589, 0.8178, 0.9258,
#          0.3069, 0.9226, 0.3649, 0.3673, 0.0824, 0.5950, 0.0037, 0.6057, 0.9530,
#          0.0237, 0.6564, 0.8438, 0.4741, 0.4340, 0.2827, 0.1027, 0.3828, 0.8556,
# ...

# %%
gwv = load_graphs(wordvg)[0][0]
gwv.ndata
# Out:
# {'_FVULN': tensor([0., 0., 0., 0.]), '_VULN': tensor([0., 0., 0., 0.]), '_LINE': tensor([2, 6, 3, 4], dtype=torch.int32), '_RANDFEAT': tensor([[0.3451, 0.5914, 0.1032, 0.6897, 0.5777, 0.2284, 0.4767, 0.7269, 0.1604,
#          0.9718, 0.8433, 0.0855, 0.6772, 0.0911, 0.4352, 0.1244, 0.2707, 0.9129,
#          0.1812, 0.1037, 0.7897, 0.9137, 0.1924, 0.7588, 0.0685, 0.1873, 0.4675,
#          0.8208, 0.8189, 0.2360, 0.0407, 0.3229, 0.5381, 0.7273, 0.1876, 0.1483,
#          0.0540, 0.2495, 0.2330, 0.8226, 0.2134, 0.4189, 0.1467, 0.4351, 0.9911,
#          0.1829, 0.6458, 0.1672, 0.6435, 0.9073, 0.1767, 0.0938, 0.7250, 0.3388,
#          0.8744, 0.7096, 0.9875, 0.6085, 0.2608, 0.9775, 0.9030, 0.1815, 0.5369,
#          0.6338, 0.5628, 0.8798, 0.7685, 0.4812, 0.0486, 0.5510, 0.4274, 0.4740,
#          0.3030, 0.3849, 0.6817, 0.5326, 0.0464, 0.9979, 0.0994, 0.5852, 0.9201,
#          0.8783, 0.3440, 0.9943, 0.0957, 0.7881, 0.2454, 0.0253, 0.6373, 0.6628,
# ...
